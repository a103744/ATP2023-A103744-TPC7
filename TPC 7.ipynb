# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
#Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula

resPol = []
def criaPolIn():
    polinomios = int(input("quantos polinómios quer ter?"))
    while polinomios > 0:
        resMon =[]
        termo = int(input("quantos termos tem o polinomio?"))
        while termo > 0:
            coeficiente = float(input("qual é o coeficiente"))
            expoente = int(input("qual é o expoente?")) 
            termo = termo - 1
            if coeficiente != 0:
                resMon.append((coeficiente, expoente))
        resPol.append(resMon)
        polinomios = polinomios - 1
    print(resPol)
    return resPol


def guardarPolinomios(fnome):
    fpol = open(fnome, "w")
    for pol in resPol:
        for monomio in pol:
            coef, exp = monomio
            fpol.write(str(coef) + ", " + str(exp) + " |")
        fpol.write("\n") 
    fpol.close
    return

def lerPolinomios(fnome):
    res = []
    fpol = open(fnome)
    for linha in fpol:
        pol = []
        termos = linha.split("|") #tira o |
        termos.remove ("\n") 
        for t in termos:
            monomio = t.split(",")
            pol.append((float(monomio[0]), int(monomio[1])))
        res.append(pol)
    fpol.close()
    return res

def listarPolinomios(fnome):
    n = 1
    fpol = open(fnome)
    print ("ordem || monómio")
    print ("----------------------------------------------")
    for linha in fpol:
        pol = ()
        termos = linha.split("|") #tira o |
        termos.remove ("\n") 
        res = ""
        for t in termos:
            monomio = t.split(",")
            coef, exp = monomio
            if float(coef) < 0:
                res = (f"{res}{str(coef)}")
            else:
                res = (f"{res}+{str(coef)}")
            if float(coef) != 0:
                if exp != 0:
                    res = (f"{res}x^{str(exp)}")    
                    pol = (res)
        print (f"  {n}   ||  {pol} ")
        n = n + 1
        print ("----------------------------------------------")
    fpol.close()

def calcPolinomio(p, x):
    res = 0
    for termo in p:
        coef, exp = termo #abrir o tuplo
        res = res + (x**exp)*coef # ** é operação de elevar

    return res

def listarPolinomiosGrau(fnome):
    n = 1
    fpol = open(fnome)
    print ("ordem || grau || monómio")
    print ("--------------------------------------------------------")
    for linha in fpol:
        pol = ()
        termos = linha.split("|") #tira o |
        termos.remove ("\n") 
        res = ""
        maior = 0
        for t in termos:
            monomio = t.split(",")
            coef, exp = monomio
            if float(coef) < 0:
                res = (f"{res}{str(coef)}")
            else:
                res = (f"{res}+{str(coef)}")
            if float(coef) != 0:
                if exp != 0:
                    res = (f"{res}x^{str(exp)}")    
                    pol = (res)
            if int(exp) > int(maior):
                maior = exp
        print (f"  {n}   ||  {maior} || {pol} ")
        n = n + 1
        print ("--------------------------------------------------------")
    fpol.close()

def grauPolinomios(fnome):
    maior = 0
    ordem = 0
    a =()
    n = 1
    fpol = open(fnome)
    for linha in fpol:
        pol = ()
        termos = linha.split("|") #tira o |
        termos.remove ("\n") 
        res = ""
        ordem = ordem + 1
        for t in termos:
            monomio = t.split(",")    
            coef, exp = monomio
            if int(exp) > int(maior):
                maior = exp
                a = (maior, ordem)
    print(a)

def derivada(fnome):
    fpol = open(fnome)
    print ("polinómio || derivada")
    print ("---------------------------------------------------------")
    for linha in fpol:
        poli = []
        termos = linha.split("|") #tira o |
        termos.remove ("\n")
        for t in termos:
            monomio = t.split(",")
            poli.append((float(monomio[0]), int(monomio[1])))
            res = ""
            deriv = []
            for n in poli:
                coef, exp = n
                if float(coef) < 0:
                    res = (f"{res}{str(coef)}")
                else:
                    res = (f"{res}+{str(coef)}")
                if float(coef) != 0:
                    if exp != 0:
                        res = (f"{res}x^{str(exp)}")

                coef = coef * exp
                exp = exp - 1
                deriv.append((coef, exp))
                resd = ""
                for d in deriv:  
                    coefd, expd = d
                    if float(coefd) < 0:
                        resd = (f"{resd}{str(coefd)}")
                    elif float(coefd) > 0:
                        resd = (f"{resd}+{str(coefd)}")
                    if float(coefd) != 0:
                        if expd != 0:
                            resd = (f"{resd}x^{str(expd)}")
        print (f"{res} || {resd}")
        print ("---------------------------------------------------------")
    fpol.close()
   

def soma(pol1, pol2):
    coefres = 0
    expres = 0
    npol = ()
    soma = []
    for coef1, exp1 in pol1:
        encontrado = False
        for coef2, exp2 in pol2:
            if exp1 == exp2:
                coefres = coef1 +coef2
                npol = (coefres, exp1)
                soma.append(npol)
                encontrado = True
        if encontrado == False:
            npol = (coef1, exp1)
            soma.append(npol) 
    for coef2, exp2 in pol2:
        encontrado = False
        for coef1, exp1 in pol1:
            if exp1 == exp2:
                encontrado = True 
        if encontrado == False:
            npol = (coef2, exp2)
            soma.append(npol)

    x = sorted(soma, reverse = True, key= lambda x: x[1])
    res = ""
    for n in x:
        coef, exp = n
        if float(coef) < 0:
            res = (f"{res}{str(coef)}")
        else:
            res = (f"{res}+{str(coef)}")
        if float(coef) != 0:
            if exp != 0:
                res = (f"{res}x^{str(exp)}")

    print (res)

def desenhaGráfico(p):
    import matplotlib.pyplot as plt
    import numpy as np 
    coeficientes = []
    for monomio in p:
        coef, exp = monomio
        coeficientes.append(coef)
    x = np.linspace(-10, 10, 400)  # Valores de -10 a 10, 400 pontos no gráfico
    y = sum(coef * x ** exp for exp, coef in enumerate(coeficientes))

    plt.plot(x, y, label=f"Polinômio: {p} ")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Gráfico de um Polinômio")
    plt.grid(True)
    plt.legend()
    plt.show()

def menu():
    print("""1. Criar um polinómio;
    2. Ler lista de polinómios;
    3. Listar polinómios;
    4. Calcular o valor de um polinómio num ponto;
    5. Listar polinómios com grau;
    6. Maior grau;
    7. Derivada;
    8. Somar dois polinómios;
    9. Gerar um gráfico para o polinómio;
    10. Gravar num ficheiro os polinómios em memória;
    0. Sair da aplicação""")

escolha = -1
print(menu())
while escolha != 0:
    escolha = int(input("Selecione a opção que quer"))
    if escolha == 1:
        criaPolIn()
    if escolha == 2:
        print(lerPolinomios("polinomios2.txt"))
    if escolha == 3:
        listarPolinomios("polinomios2.txt")
    if escolha== 4:
        p = int(input("Qual a ordem do polinómio que quer?"))
        x = int(input("Qual é o valor de x que quer?"))
        print(calcPolinomio(lerPolinomios("polinomios2.txt")[(p-1)], x))
    if escolha == 5:
        listarPolinomiosGrau("polinomios2.txt")
    if escolha == 6:
        grauPolinomios("polinomios2.txt")
    if escolha == 7:
        derivada("polinomios2.txt")
    if escolha == 8:
       pol1 = int(input("Qual é o primeiro polinómio?"))
       pol2 = int(input("Qual é o outro polinómio?"))
       soma(calcPolinomio(lerPolinomios("polinomios2.txt")[(pol1-1)], calcPolinomio(lerPolinomios("polinomios2.txt")[(pol2-1)])))
    if escolha == 9:
       p = int(input("Qual a ordem do polinómio que quer?"))
       desenhaGráfico(lerPolinomios("polinomios2.txt")[(p-1)]) 
    if escolha == 10:
        guardarPolinomios("polinomios2.txt")
# Out:
# 1. Criar um polinómio;
#     2. Ler lista de polinómios;
#     3. Listar polinómios;
#     4. Calcular o valor de um polinómio num ponto;
#     5. Listar polinómios com grau;
#     6. Maior grau;
#     7. Derivada;
#     8. Somar dois polinómios;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação
# None
# [[(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)]]
# [[(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)], [(2.0, 2), (17.0, 0)], [(7.0, 4), (6.0, 3), (-1.0, 2), (43.0, 0)]]
# [[(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)], [(2.0, 2), (17.0, 0)], [(7.0, 4), (6.0, 3), (-1.0, 2), (43.0, 0)]]
